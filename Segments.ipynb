# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df1=pd.read_csv("EV_Customer_Feedback.csv")
df1.head()
# Out:
#                                               review    Used it for  \
# 0  We all checked the bike's capacity to be 150 k...  Daily Commute
# 1  Performance is very poor on this bike. The cha...     Everything
# 2  I purchased this in April 2022 and the sales s...  Daily Commute
# 3  If any issues come in scooty parts not availab...  Daily Commute
# 4  Don't buy this vehicle unless you have a near ...  Daily Commute
#
#        Owned for      Ridden for  rating  Visual Appeal  Reliability  \
# 0    Never owned             NaN       1            3.0          4.0
# 1         > 1 yr      < 5000 kms       1            3.0          1.0
# 2     < 3 months      < 5000 kms       3            4.0          4.0
# 3  6 months-1 yr  5000-10000 kms       1            1.0          1.0
# 4  6 months-1 yr      < 5000 kms       1            3.0          4.0
#
#    Performance  Service Experience  Extra Features  Comfort  Maintenance cost  \
# ...

# %%
df2=pd.read_csv("Cheapestelectriccars-EVDatabase.csv")
df2.head()
# Out:
#                                Name  \
# 0                    Opel Ampera-e
# 1         Renault Kangoo Maxi ZE 33
# 2                      Nissan Leaf
# 3  Audi e-tron Sportback 55 quattro
# 4            Porsche Taycan Turbo S
#
#                                     Subtitle Acceleration  TopSpeed   Range  \
# 0   Battery Electric Vehicle |       58 kWh       7.3 sec  150 km/h  335 km
# 1   Battery Electric Vehicle |       31 kWh      22.4 sec  130 km/h  160 km
# 2   Battery Electric Vehicle |       36 kWh       7.9 sec  144 km/h  220 km
# 3  Battery Electric Vehicle |       86.5 kWh      5.7 sec  200 km/h  375 km
# 4  Battery Electric Vehicle |       83.7 kWh      2.8 sec  260 km/h  390 km
#
#   Efficiency FastChargeSpeed              Drive  NumberofSeats PriceinGermany  \
# 0  173 Wh/km        210 km/h  Front Wheel Drive              5        €42,990
# 1  194 Wh/km               -  Front Wheel Drive              5            NaN
# ...

# %%
df3=pd.read_csv("Quickestelectriccars-EVDatabase.csv")
df3.head()
# Out:
#                                    Name  \
# 0                       Tesla Roadster
# 1                   Tesla Model X Plaid
# 2                Porsche Taycan Turbo S
# 3  Porsche Taycan Turbo S Cross Turismo
# 4            Tesla Cybertruck Tri Motor
#
#                                     Subtitle Acceleration  TopSpeed   Range  \
# 0  Battery Electric Vehicle |       200 kWh       2.1 sec  410 km/h  970 km
# 1   Battery Electric Vehicle |       90 kWh       2.6 sec  262 km/h  455 km
# 2  Battery Electric Vehicle |       83.7 kWh      2.8 sec  260 km/h  390 km
# 3  Battery Electric Vehicle |       83.7 kWh      2.9 sec  250 km/h  380 km
# 4  Battery Electric Vehicle |       200 kWh       3.0 sec  210 km/h  750 km
#
#   Efficiency FastChargeSpeed            Drive  NumberofSeats PriceinGermany  \
# 0  206 Wh/km        920 km/h  All Wheel Drive              4       €215,000
# 1  198 Wh/km        680 km/h  All Wheel Drive              7       €116,990
# ...

# %%
df4=pd.read_excel("ev_market_india_data.xlsx")
df4['INR']=df4['PriceEuro']*85.06
df4.head()
# Out:
#    Unnamed: 0       Brand                          Model  AccelSec  \
# 0           0       Tesla  Model 3 Long Range Dual Motor       4.6
# 1           1  Volkswagen                      ID.3 Pure      10.0
# 2           2    Polestar                              2       4.7
# 3           3         BMW                            iX3       6.8
# 4           4       Honda                              e       9.5
#
#    TopSpeed_KmH  Range_Km  Efficiency_WhKm  FastCharge_KmH RapidCharge  \
# 0           233       450              161             940         Yes
# 1           160       270              167             250          No
# 2           210       400              181             620         Yes
# 3           180       360              206             560         Yes
# 4           145       170              168             190         Yes
#
#   PowerTrain    PlugType  BodyStyle Segment  Seats  PriceEuro         INR
# ...

# %%
df5=pd.read_csv("EVIndia.csv")
df5.head()
# Out:
#                      Car             Style               Range Transmission  \
# 0          Tata Nexon EV       Compact SUV  312 Km/Full Charge    Automatic
# 1          Tata Tigor EV  Subcompact Sedan  306 Km/Full Charge    Automatic
# 2      Tata Nexon EV Max       Compact SUV  437 Km/Full Charge    Automatic
# 3               MG ZS EV       Compact SUV  419 Km/Full Charge    Automatic
# 4  Hyundai Kona Electric       Compact SUV  452 Km/Full Charge    Automatic
#
#   VehicleType         PriceRange   Capacity BootSpace           BaseModel  \
# 0    Electric   ₹ 13.99 - 17.4 L  5 Seater      350 L                 XM
# 1    Electric  ₹ 12.49 - 13.64 L  5 Seater      316 L                 XE
# 2    Electric  ₹ 17.74 - 19.24 L  5 Seater      350 L     XZ Plus 3.3 kW
# 3    Electric  ₹ 21.99 - 25.88 L  5 Seater      448 L             Excite
# 4    Electric  ₹ 23.79 - 23.98 L  5 Seater         na  Premium Dual Tone
#
#               TopModel
# 0    Dark XZ Plus LUX
# ...

# %%
df6=pd.read_csv("StatewiseSales.csv")
df6=df6.set_index('State')
df6.head()
# Out:
#                   Sales
# State
# Jammu Kashmir      1036
# Himachal Pradesh    446
# Punjab             2977
# Chandigarh          154
# Uttarakhand        2288

# %%
plt.rcParams['figure.figsize']=(18,12)
plt.subplot(221)
sns.countplot(data=df1,x='rating',hue='Used it for')
plt.subplot(222)
sns.countplot(data=df1,x='rating',hue='Value for Money')
plt.subplot(223)
sns.countplot(data=df1,x='rating',hue='Visual Appeal')
plt.subplot(224)
sns.countplot(data=df1,x='rating',hue='Comfort')
# Out:
# <AxesSubplot:xlabel='rating', ylabel='count'>

# %%
df1[['Value for Money','Visual Appeal','Comfort','rating']].corr().style.background_gradient(cmap='RdBu_r')
# Out:
# <style type="text/css">
# #T_3e911_row0_col0, #T_3e911_row1_col1, #T_3e911_row2_col2, #T_3e911_row3_col3 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_3e911_row0_col1, #T_3e911_row0_col2, #T_3e911_row1_col0, #T_3e911_row1_col3 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_3e911_row0_col3 {
#   background-color: #deebf2;
#   color: #000000;
# }
# #T_3e911_row1_col2 {
#   background-color: #10457e;
#   color: #f1f1f1;
# }
# #T_3e911_row2_col0 {
#   background-color: #2e77b5;
#   color: #f1f1f1;
# }
# #T_3e911_row2_col1 {
#   background-color: #3a87bd;
#   color: #f1f1f1;
# }
# #T_3e911_row2_col3 {
#   background-color: #7eb8d7;
#   color: #000000;
# }
# #T_3e911_row3_col0 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_3e911_row3_col1 {
#   background-color: #2267ac;
#   color: #f1f1f1;
# }
# #T_3e911_row3_col2 {
#   background-color: #65a9cf;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3e911">
#   <thead>
#     <tr>
# ...

# %%
plt.rcParams['figure.figsize']=(18,12)
LIST=[i for i in range(103)]
plt.subplot(321)
plt.scatter(LIST,df4['AccelSec'])
plt.ylabel("Acceleration(Sec)")
plt.subplot(322)
plt.scatter(LIST,df4['TopSpeed_KmH'])
plt.ylabel("Top Speed(KmH)")
plt.subplot(323)
plt.scatter(LIST,df4['Efficiency_WhKm'])
plt.ylabel("Efficiency(WhKm)")
plt.subplot(324)
plt.scatter(LIST,df4['Range_Km'])
plt.ylabel("Range(Km)")
plt.subplot(325)
sns.countplot(data=df4,x='Seats')
plt.subplot(326)
plt.scatter(LIST,df4['INR'])
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.rcParams['figure.figsize']=(18,6)
df6.plot.bar()
# Out:
# <AxesSubplot:xlabel='State'>
